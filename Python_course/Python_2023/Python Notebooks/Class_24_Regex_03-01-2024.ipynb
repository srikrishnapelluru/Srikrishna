# %%
'''
.       - Any Character Except New Line
\d      - Digit (0-9)
\D      - Not a Digit (0-9)
\w      - Word Character (a-z, A-Z, 0-9, _)
\W      - Not a Word Character
\s      - Whitespace (space, tab, newline)
\S      - Not Whitespace (space, tab, newline)

\b      - Word Boundary
\B      - Not a Word Boundary
^       - Beginning of a String
$       - End of a String

[]      - Matches Characters in brackets
[^ ]    - Matches Characters NOT in brackets
|       - Either Or
( )     - Group

Quantifiers:
*       - 0 or More
+       - 1 or More
?       - 0 or One
{3}     - Exact Number
{3,4}   - Range of Numbers (Minimum, Maximum)
'''

# %%
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ\s
321-555-4321
1234567890
Ha HaHa
MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )
Salahuddin@TCS.com
321-555-4321
123.555.1234
123*555*1234
123.555.1234
800-555-1234
900-555-1234
Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
Mr_hello
'''

# %% [markdown]
# # Regular expression

# %%
import re

# %%
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ\s
321-555-4321
1234567890
Ha HaHa
MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )
Salahuddin@TCS.com
321-555-4321
123.555.1234
123*555*1234
123.555.1234
800-555-1234
900-555-1234
Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
Mr_hello
abc
'''

text_to_search[1:4]
# Out:
# 'abc'

# %%
# What you want to search

patt = re.compile('abc')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(1, 4), match='abc'>
# <re.Match object; span=(310, 313), match='abc'>

# %%
# What you want to search

patt = re.compile('abc')

# Which string you are searching for

results = patt.findall(text_to_search)

for i in results:
    print(i)
# Out:
# abc
# abc

# %%
list(re.finditer('abc' , text_to_search))
# Out:
# [<re.Match object; span=(1, 4), match='abc'>,
#  <re.Match object; span=(310, 313), match='abc'>]

# %%
# . dot

# %%
# What you want to search

patt = re.compile('.')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='u'>
# <re.Match object; span=(19, 20), match='r'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %%
# \d


# What you want to search

patt = re.compile('\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 58), match='3'>
# <re.Match object; span=(58, 59), match='2'>
# <re.Match object; span=(59, 60), match='1'>
# <re.Match object; span=(61, 62), match='5'>
# <re.Match object; span=(62, 63), match='5'>
# <re.Match object; span=(63, 64), match='5'>
# <re.Match object; span=(65, 66), match='4'>
# <re.Match object; span=(66, 67), match='3'>
# <re.Match object; span=(67, 68), match='2'>
# <re.Match object; span=(68, 69), match='1'>
# <re.Match object; span=(70, 71), match='1'>
# <re.Match object; span=(71, 72), match='2'>
# <re.Match object; span=(72, 73), match='3'>
# <re.Match object; span=(73, 74), match='4'>
# <re.Match object; span=(74, 75), match='5'>
# <re.Match object; span=(75, 76), match='6'>
# <re.Match object; span=(76, 77), match='7'>
# <re.Match object; span=(77, 78), match='8'>
# <re.Match object; span=(78, 79), match='9'>
# <re.Match object; span=(79, 80), match='0'>
# <re.Match object; span=(173, 174), match='3'>
# ...

# %%
# \D


# What you want to search

patt = re.compile('\D')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='u'>
# <re.Match object; span=(19, 20), match='r'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# ...

# %%
# \w


# What you want to search

patt = re.compile('\w')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='u'>
# <re.Match object; span=(19, 20), match='r'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %%
# \W


# What you want to search

patt = re.compile('\W')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(54, 55), match='\\'>
# <re.Match object; span=(56, 57), match='\n'>
# <re.Match object; span=(60, 61), match='-'>
# <re.Match object; span=(64, 65), match='-'>
# <re.Match object; span=(69, 70), match='\n'>
# <re.Match object; span=(80, 81), match='\n'>
# <re.Match object; span=(83, 84), match=' '>
# <re.Match object; span=(88, 89), match='\n'>
# <re.Match object; span=(103, 104), match=' '>
# <re.Match object; span=(104, 105), match='('>
# <re.Match object; span=(109, 110), match=' '>
# <re.Match object; span=(112, 113), match=' '>
# <re.Match object; span=(115, 116), match=' '>
# <re.Match object; span=(123, 124), match=')'>
# <re.Match object; span=(124, 125), match=':'>
# <re.Match object; span=(125, 126), match='\n'>
# <re.Match object; span=(126, 127), match='.'>
# <re.Match object; span=(127, 128), match=' '>
# <re.Match object; span=(128, 129), match='^'>
# ...

# %%
# \s


# What you want to search

patt = re.compile('\s')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(56, 57), match='\n'>
# <re.Match object; span=(69, 70), match='\n'>
# <re.Match object; span=(80, 81), match='\n'>
# <re.Match object; span=(83, 84), match=' '>
# <re.Match object; span=(88, 89), match='\n'>
# <re.Match object; span=(103, 104), match=' '>
# <re.Match object; span=(109, 110), match=' '>
# <re.Match object; span=(112, 113), match=' '>
# <re.Match object; span=(115, 116), match=' '>
# <re.Match object; span=(125, 126), match='\n'>
# <re.Match object; span=(127, 128), match=' '>
# <re.Match object; span=(129, 130), match=' '>
# <re.Match object; span=(131, 132), match=' '>
# <re.Match object; span=(133, 134), match=' '>
# <re.Match object; span=(135, 136), match=' '>
# <re.Match object; span=(137, 138), match=' '>
# <re.Match object; span=(139, 140), match=' '>
# <re.Match object; span=(141, 142), match=' '>
# <re.Match object; span=(143, 144), match=' '>
# ...

# %%
# \S


# What you want to search

patt = re.compile('\S')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='u'>
# <re.Match object; span=(19, 20), match='r'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# <re.Match object; span=(22, 23), match='v'>
# ...

# %%
# Extract the mobile numbers

# What you want to search

patt = re.compile('\d\d\d.\d\d\d.\d\d\d\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(186, 198), match='123.555.1234'>
# <re.Match object; span=(199, 211), match='123*555*1234'>
# <re.Match object; span=(212, 224), match='123.555.1234'>
# <re.Match object; span=(225, 237), match='800-555-1234'>
# <re.Match object; span=(238, 250), match='900-555-1234'>

# %%
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ\s
321-555-4321
1234567890
Ha HaHa
MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )
Salahuddin@TCS.com
321-555-4321
123.555.1234
123*555*1234
123.555.1234
800-555-1234
900-555-1234
Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
Mr_hello
abc
'''

# %%
string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile('cat')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(4, 7), match='cat'>
# <re.Match object; span=(14, 17), match='cat'>
# <re.Match object; span=(27, 30), match='cat'>
# <re.Match object; span=(36, 39), match='cat'>
# <re.Match object; span=(42, 45), match='cat'>
# <re.Match object; span=(54, 57), match='cat'>

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'\bcat')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(4, 7), match='cat'>
# <re.Match object; span=(14, 17), match='cat'>

# %%
a = r'hello\bworld'

print(a)
# Out:
# hello\bworld

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'cat\b')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(27, 30), match='cat'>
# <re.Match object; span=(36, 39), match='cat'>

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'\bcat\b')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'\Bcat')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(27, 30), match='cat'>
# <re.Match object; span=(36, 39), match='cat'>
# <re.Match object; span=(42, 45), match='cat'>
# <re.Match object; span=(54, 57), match='cat'>

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'\Bcat\B')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(42, 45), match='cat'>
# <re.Match object; span=(54, 57), match='cat'>

# %%
# \b word bounda

string = 'cat catherine catholic copycat blackcat uncatchable locator'

# What you want to search

patt = re.compile(r'\Bcat\B')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(42, 45), match='cat'>
# <re.Match object; span=(54, 57), match='cat'>

# %%
string = '123_xyz@gmail.com'

# What you want to search

patt = re.compile(r'^\d')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='123'>

# %%
string = '123_xyz@gmail.com'

# What you want to search

patt = re.compile(r'\w$')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(16, 17), match='m'>

# %%
string = 'bat rat hat mat fat cat'

# What you want to search

patt = re.compile(r'[rh]at')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(4, 7), match='rat'>
# <re.Match object; span=(8, 11), match='hat'>

# %%
# a-g

string = 'bat rat hat mat fat cat'

# What you want to search

patt = re.compile(r'[abcdefg]at')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='bat'>
# <re.Match object; span=(16, 19), match='fat'>
# <re.Match object; span=(20, 23), match='cat'>

# %%
# a-g

string = 'bat rat hat mat fat cat'

# What you want to search

patt = re.compile(r'[a-g]at')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='bat'>
# <re.Match object; span=(16, 19), match='fat'>
# <re.Match object; span=(20, 23), match='cat'>

# %%
# a-g

string = 'Bat rat Hat mat fat cat'

# What you want to search

patt = re.compile(r'[a-gA-G0-5]at')

# Which string you are searching for

results = patt.finditer(string)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='Bat'>
# <re.Match object; span=(16, 19), match='fat'>
# <re.Match object; span=(20, 23), match='cat'>

# %%
# What you want to search

patt = re.compile('[89]\d\d.\d\d\d.\d\d\d\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(225, 237), match='800-555-1234'>
# <re.Match object; span=(238, 250), match='900-555-1234'>

# %%
# What you want to search

patt = re.compile('\d\d\d\.\d\d\d\.\d\d\d\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(186, 198), match='123.555.1234'>
# <re.Match object; span=(212, 224), match='123.555.1234'>

# %%
# What you want to search

patt = re.compile('\d\d\d[*-]\d\d\d[*-]\d\d\d\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(199, 211), match='123*555*1234'>
# <re.Match object; span=(225, 237), match='800-555-1234'>
# <re.Match object; span=(238, 250), match='900-555-1234'>

# %%
# What you want to search

patt = re.compile('[^89]\d\d.\d\d\d.\d\d\d\d')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(186, 198), match='123.555.1234'>
# <re.Match object; span=(199, 211), match='123*555*1234'>
# <re.Match object; span=(212, 224), match='123.555.1234'>

# %%
# What you want to search

patt = re.compile('\d{3}.\d{3}.\d{4}')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(186, 198), match='123.555.1234'>
# <re.Match object; span=(199, 211), match='123*555*1234'>
# <re.Match object; span=(212, 224), match='123.555.1234'>
# <re.Match object; span=(225, 237), match='800-555-1234'>
# <re.Match object; span=(238, 250), match='900-555-1234'>

# %%
# What you want to search

patt = re.compile('\d{3}.\d{3}.\d{4}')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(186, 198), match='123.555.1234'>
# <re.Match object; span=(203, 215), match='123*555*1234'>
# <re.Match object; span=(217, 229), match='123.555.1234'>
# <re.Match object; span=(230, 242), match='800-555-1234'>
# <re.Match object; span=(245, 257), match='900-555-1234'>

# %%
# What you want to search

patt = re.compile('\d{3}.\d{3}.\d{4,8}')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(57, 69), match='321-555-4321'>
# <re.Match object; span=(173, 185), match='321-555-4321'>
# <re.Match object; span=(186, 202), match='123.555.12345678'>
# <re.Match object; span=(203, 216), match='123*555*12345'>
# <re.Match object; span=(217, 229), match='123.555.1234'>
# <re.Match object; span=(230, 244), match='800-555-123456'>
# <re.Match object; span=(245, 257), match='900-555-1234'>

# %%
# What you want to search

patt = re.compile(r'M')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(40, 41), match='M'>
# <re.Match object; span=(89, 90), match='M'>
# <re.Match object; span=(258, 259), match='M'>
# <re.Match object; span=(270, 271), match='M'>
# <re.Match object; span=(279, 280), match='M'>
# <re.Match object; span=(288, 289), match='M'>
# <re.Match object; span=(302, 303), match='M'>
# <re.Match object; span=(308, 309), match='M'>

# %%
# What you want to search

patt = re.compile(r'Mr')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 260), match='Mr'>
# <re.Match object; span=(270, 272), match='Mr'>
# <re.Match object; span=(288, 290), match='Mr'>
# <re.Match object; span=(302, 304), match='Mr'>
# <re.Match object; span=(308, 310), match='Mr'>

# %%
# What you want to search

patt = re.compile(r'Mr\.')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 261), match='Mr.'>
# <re.Match object; span=(302, 305), match='Mr.'>

# %%
# What you want to search

patt = re.compile(r'Mr\.\s[A-Z]')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 263), match='Mr. S'>
# <re.Match object; span=(302, 307), match='Mr. T'>

# %%
# What you want to search

patt = re.compile(r'Mr\.\s[A-Z][a-z]*')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(302, 307), match='Mr. T'>

# %%
# What you want to search

patt = re.compile(r'Mr\.\s[A-Z][a-z]+')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>

# %%
# What you want to search

patt = re.compile(r'Mr\.?\s[A-Z][a-z]*')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(302, 307), match='Mr. T'>

# %%
# What you want to search

patt = re.compile(r'M(r|s|rs)\.?\s[A-Z][a-z]*')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(279, 287), match='Ms Davis'>
# <re.Match object; span=(288, 301), match='Mrs. Robinson'>
# <re.Match object; span=(302, 307), match='Mr. T'>

# %%
# What you want to search

patt = re.compile(r'M(r|s|rs).*')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(279, 287), match='Ms Davis'>
# <re.Match object; span=(288, 301), match='Mrs. Robinson'>
# <re.Match object; span=(302, 307), match='Mr. T'>
# <re.Match object; span=(308, 316), match='Mr_hello'>

# %%
# What you want to search

patt = re.compile(r'M(r|s)s?(_|\.)?\s?[A-Za-z]*')

# Which string you are searching for

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(279, 287), match='Ms Davis'>
# <re.Match object; span=(288, 301), match='Mrs. Robinson'>
# <re.Match object; span=(302, 307), match='Mr. T'>
# <re.Match object; span=(308, 316), match='Mr_hello'>

# %%
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ\s
321-555-4321
1234567890
Ha HaHa
MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )
Salahuddin@TCS.com
321-555-4321
123.555.12345678
123*555*12345
123.555.1234
800-555-123456
900-555-1234
Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
Mr_hello
'''

# %%
patt = re.compile(r'M(r|s|rs)(\.?|_?|\s?)([A-Z]?|[a-z]).*')

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(279, 287), match='Ms Davis'>
# <re.Match object; span=(288, 301), match='Mrs. Robinson'>
# <re.Match object; span=(302, 307), match='Mr. T'>
# <re.Match object; span=(308, 316), match='Mr_hello'>

# %% [markdown]
# # Numpy

# %%
patt = re.compile(r'M(r|s)s?\.?\s?\_?[A-Za-z]*')

results = patt.finditer(text_to_search)

for i in results:
    print(i)
# Out:
# <re.Match object; span=(258, 269), match='Mr. Schafer'>
# <re.Match object; span=(270, 278), match='Mr Smith'>
# <re.Match object; span=(279, 287), match='Ms Davis'>
# <re.Match object; span=(288, 301), match='Mrs. Robinson'>
# <re.Match object; span=(302, 307), match='Mr. T'>
# <re.Match object; span=(308, 316), match='Mr_hello'>
