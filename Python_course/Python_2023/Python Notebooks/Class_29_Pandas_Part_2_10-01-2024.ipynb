# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas basic function

# %%
df = pd.read_csv('datasets/weather_data.csv')

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Shape

df.shape
# Out:
# (6, 4)

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df.shape
# Out:
# (32428, 10)

# %%
# Head

# %%
df.head(10)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
df.head(1)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
#
#   name_localizedValue    usertype
# 0   Annual Membership  Subscriber

# %% [markdown]
# # Tail

# %%
df.tail()
# Out:
#        tripduration            starttime             stoptime  \
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32423              3184          Paulus Hook            3279      Dixon Mills
# 32424              3202         Newport PATH            3639       Harborside
# 32425              3220    5 Corners Library            3195          Sip Ave
# 32426              3281  Leonard Gordon Park            3213   Van Vorst Park
# 32427              3220    5 Corners Library            3207      Oakland Ave
#
#        bikeid              name_localizedValue    usertype
# 32423   29639  Join Citi Bike for $14.95/month  Subscriber
# ...

# %%
df.tail(2)
# Out:
#        tripduration            starttime             stoptime  \
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32426              3281  Leonard Gordon Park            3213   Van Vorst Park
# 32427              3220    5 Corners Library            3207      Oakland Ave
#
#        bikeid name_localizedValue    usertype
# 32426   26239   Annual Membership  Subscriber
# 32427   33660   Annual Membership  Subscriber

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# # Describe

# %%
df.describe()
# Out:
#         tripduration  start station id  end station id        bikeid
# count   32428.000000      32428.000000    32428.000000  32428.000000
# mean      798.978352       3264.568829     3255.485568  29817.647959
# std      9961.203954        137.810344      149.390306   2807.705863
# min        61.000000       3183.000000      212.000000  15271.000000
# 25%       236.000000       3192.000000     3186.000000  26310.000000
# 50%       352.000000       3206.000000     3203.000000  29516.000000
# 75%       590.000000       3272.000000     3270.000000  33568.000000
# max    936970.000000       3681.000000     3681.000000  33682.000000

# %%
df.describe(include = 'object')
# Out:
#                   starttime             stoptime start station name  \
# count                 32428                32428              32428
# unique                31859                31899                 50
# top     2018-05-11 16:28:13  2018-05-25 09:10:30      Grove St PATH
# freq                      3                    3               3313
#
#        end station name name_localizedValue    usertype
# count             32428               32428       32428
# unique               61                  32           2
# top       Grove St PATH   Annual Membership  Subscriber
# freq               4720               20056       30053

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df = pd.read_csv('datasets/weather_data.csv')

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.describe(include = 'object')
# Out:
#              day event
# count          6     6
# unique         6     3
# top     1/1/2017  Rain
# freq           1     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %% [markdown]
# # Indexing and slicing

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
# Selecting 1 column

df['bikeid']
# Out:
# 0        33558
# 1        33593
# 2        29217
# 3        29662
# 4        15271
#          ...
# 32423    29639
# 32424    26301
# 32425    29260
# 32426    26239
# 32427    33660
# Name: bikeid, Length: 32428, dtype: int64

# %%
# Selecting multiple columns

df[['bikeid' , 'tripduration' , 'tripduration']]
# Out:
#        bikeid  tripduration  tripduration
# 0       33558           338           338
# 1       33593          1482          1482
# 2       29217           232           232
# 3       29662           190           190
# 4       15271           303           303
# ...       ...           ...           ...
# 32423   29639           396           396
# 32424   26301           313           313
# 32425   29260           316           316
# 32426   26239          1130          1130
# 32427   33660           369           369
#
# [32428 rows x 3 columns]

# %%
# display me the top 10 bikeid

df['bikeid'].head(10)
# Out:
# 0    33558
# 1    33593
# 2    29217
# 3    29662
# 4    15271
# 5    29298
# 6    33619
# 7    33624
# 8    26300
# 9    33555
# Name: bikeid, dtype: int64

# %%
a = df['start station name']

type(a)
# Out:
# pandas.core.series.Series

# %%
df['start station name'][3]
# Out:
# 'City Hall'

# %%
df.at[3, 'start station name']


# at[row , column]
# Out:
# 'City Hall'

# %%
df['tripduration'][2] = 300
# Out:
# C:\Users\Mohammed Israr\AppData\Local\Temp\ipykernel_12680\389567740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tripduration'][2] = 300

# %%
df.at[3 , 'tripduration'] = 200

# %% [markdown]
# # Slicing
#
# - The op if slicing will always give you a new dataframe

# %%
new_df = df.head(10)

e_list = []

for i in new_df.index:
    e_list.append(f'row_{i}')
    
new_df.index = e_list

new_df
# Out:
#        tripduration            starttime             stoptime  \
# row_0           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# row_6           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# row_7           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# row_8           395  2018-05-01 05:12:07  2018-05-01 05:18:42
# row_9           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#        start station id     start station name  end station id  \
# row_0              3639             Harborside            3199
# row_1              3681               Grand St            3185
# row_2              3194        McGinley Square            3193
# ...

# %%
# 1. Normal slicing
- Slicing is possible only on rows not on column

* zero indexing
- start is inclusive
- stop is exclusive

* custom indexing 
- start is inclusive
- stop is inclusive


# 2. loc method

- Slicing on column is also possible

syntax
dataframe.loc[rows , column]

* custom indexing 
- start is inclusive
- stop is inclusive


# 3. iloc method

- Slicing on column is also possible

syntax
dataframe.iloc[rows , column]

* zero indexing
- start is inclusive
- stop is exclusive

# %%
new_df[2:6]
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
# row_5              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber
# ...

# %%
new_df[7:2:-1]
# Out:
#        tripduration            starttime             stoptime  \
# row_7           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# row_6           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id     start station name  end station id  \
# row_7              3207            Oakland Ave            3185
# row_6              3225  Baldwin at Montgomery            3186
# row_5              3194        McGinley Square            3195
# row_4              3207            Oakland Ave            3195
# row_3              3185              City Hall            3186
#
#       end station name  bikeid                   name_localizedValue  \
# row_7        City Hall   33624                     Annual Membership
# row_6    Grove St PATH   33619  Annual Membership from Citi Bike App
# ...

# %%
new_df[-2:-5:-1]
# Out:
#        tripduration            starttime             stoptime  \
# row_8           395  2018-05-01 05:12:07  2018-05-01 05:18:42
# row_7           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# row_6           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#        start station id     start station name  end station id  \
# row_8              3225  Baldwin at Montgomery            3186
# row_7              3207            Oakland Ave            3185
# row_6              3225  Baldwin at Montgomery            3186
#
#       end station name  bikeid                   name_localizedValue  \
# row_8    Grove St PATH   26300                     Annual Membership
# row_7        City Hall   33624                     Annual Membership
# row_6    Grove St PATH   33619  Annual Membership from Citi Bike App
#
#          usertype
# row_8  Subscriber
# row_7  Subscriber
# row_6  Subscriber

# %%
new_df['row_2' : 'row_5']
# Out:
#        tripduration            starttime             stoptime  \
# row_2           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_3           200  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_4           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_5           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_2              3194    McGinley Square            3193     Lincoln Park
# row_3              3185          City Hall            3186    Grove St PATH
# row_4              3207        Oakland Ave            3195          Sip Ave
# row_5              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_2   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_3   29662                                  24 Hour    Customer
# row_4   15271                        Annual Membership  Subscriber
# ...

# %%
new_df.loc[2:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 new_df.loc[2:5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1290, in _LocIndexer._getitem_axis(self, key, axis)
#    1288 if isinstance(key, slice):
#    1289     self._validate_key(key, axis)
# -> 1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
#    1292     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1321     return obj.copy(deep=False)
# ...

# %%
new_df.loc['row_2' : 'row_5' , 'starttime' : 'bikeid']
# Out:
#                  starttime             stoptime  start station id  \
# row_2  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# row_3  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# row_4  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# row_5  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#       start station name  end station id end station name  bikeid
# row_2    McGinley Square            3193     Lincoln Park   29217
# row_3          City Hall            3186    Grove St PATH   29662
# row_4        Oakland Ave            3195          Sip Ave   15271
# row_5    McGinley Square            3195          Sip Ave   29298

# %%
df.loc[1:4]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           200  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 1                                  24 Hour    Customer
# 2  FREE Bonus Month with Annual Membership  Subscriber
# 3                                  24 Hour    Customer
# ...

# %%
new_df.loc['row_1' : 'row_5':2 , 'starttime' : 'bikeid' : 2]
# Out:
#                  starttime  start station id  end station id  bikeid
# row_1  2018-05-01 01:31:10              3681            3185   33593
# row_3  2018-05-01 02:03:29              3185            3186   29662
# row_5  2018-05-01 04:37:05              3194            3195   29298

# %%
new_df.iloc['row_2' : 'row_5']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 new_df.iloc['row_2' : 'row_5']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1602, in _iLocIndexer._getitem_axis(self, key, axis)
#    1596     raise IndexError(
#    1597         "DataFrame indexer is not allowed for .iloc\n"
#    1598         "Consider using .loc for automatic alignment."
#    1599     )
#    1601 if isinstance(key, slice):
# -> 1602     return self._get_slice_axis(key, axis=axis)
#    1604 if is_iterator(key):
#    1605     key = list(key)
#
# ...

# %%
new_df.iloc[2:5 , 1:8]
# Out:
#                  starttime             stoptime  start station id  \
# row_2  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# row_3  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# row_4  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#       start station name  end station id end station name  bikeid
# row_2    McGinley Square            3193     Lincoln Park   29217
# row_3          City Hall            3186    Grove St PATH   29662
# row_4        Oakland Ave            3195          Sip Ave   15271

# %%
df.iloc[1:3]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
#
#   start station name  end station id end station name  bikeid  \
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
#
#                        name_localizedValue    usertype
# 1                                  24 Hour    Customer
# 2  FREE Bonus Month with Annual Membership  Subscriber

# %%
new_df.loc[['row_2' , 'row_3' , 'row_5'] ].loc[: , ['tripduration' , 'starttime' , 'bikeid']]
# Out:
#        tripduration            starttime  bikeid
# row_2           300  2018-05-01 01:31:29   29217
# row_3           200  2018-05-01 02:03:29   29662
# row_5           176  2018-05-01 04:37:05   29298

# %%
new_df.loc[['row_0' , 'row_3'] , ['bikeid' , 'tripduration']]
# Out:
#        bikeid  tripduration
# row_0   33558           338
# row_3   29662           200

# %%
new_df.loc[['row_2' , 'row_3' , 'row_5'] , ['tripduration' , 'starttime' , 'bikeid']]
# Out:
#        tripduration            starttime  bikeid
# row_2           300  2018-05-01 01:31:29   29217
# row_3           200  2018-05-01 02:03:29   29662
# row_5           176  2018-05-01 04:37:05   29298

# %% [markdown]
# # Filtering the data

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df.loc[df['usertype'] == 'Subscriber']
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id     start station name  end station id  \
# 0                  3639             Harborside            3199
# 2                  3194        McGinley Square            3193
# ...

# %%
df.loc[(df['usertype'] == 'Subscriber') & (df['tripduration'] >= 1000)]
# Out:
#        tripduration            starttime             stoptime  \
# 32             2056  2018-05-01 06:25:13  2018-05-01 06:59:30
# 149            1020  2018-05-01 07:51:18  2018-05-01 08:08:19
# 194            1384  2018-05-01 08:07:19  2018-05-01 08:30:24
# 220            2198  2018-05-01 08:17:07  2018-05-01 08:53:46
# 247            1278  2018-05-01 08:25:44  2018-05-01 08:47:02
# ...             ...                  ...                  ...
# 32386          1116  2018-05-30 13:05:36  2018-05-30 13:24:13
# 32388          1802  2018-05-30 13:09:34  2018-05-30 13:39:36
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32397          1770  2018-05-30 13:17:41  2018-05-30 13:47:12
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id   start station name  end station id  \
# 32                 3185            City Hall            3185
# 149                3191             Union St            3195
# ...

# %%
df.loc[(df['start station name'] == 'Harborside')|(df['start station name'] =='City Hall' )]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 3               200  2018-05-01 02:03:29  2018-05-01 02:06:40
# 11              704  2018-05-01 05:23:26  2018-05-01 05:35:11
# 32             2056  2018-05-01 06:25:13  2018-05-01 06:59:30
# 49              356  2018-05-01 06:40:07  2018-05-01 06:46:03
# ...             ...                  ...                  ...
# 32393          1152  2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266  2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249  2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...

# %%
# df -- tripduration ? 1000
# and
# start station name Harborside , City Hall 	


df.loc[((df['start station name']=='Harborside') | (df['start station name']=='City Hall')) 
       & (df['tripduration'] > 1000)]
# Out:
#        tripduration           starttime             stoptime  \
# 32             2056 2018-05-01 06:25:13  2018-05-01 06:59:30
# 394            2160 2018-05-01 09:37:02  2018-05-01 10:13:02
# 438            1583 2018-05-01 10:57:48  2018-05-01 11:24:11
# 549           21094 2018-05-01 13:45:21  2018-05-01 19:36:56
# 714            1013 2018-05-01 17:23:47  2018-05-01 17:40:40
# ...             ...                 ...                  ...
# 31562          2188 2018-05-29 20:03:34  2018-05-29 20:40:02
# 31583          5853 2018-05-29 20:14:57  2018-05-29 21:52:31
# 31589          5771 2018-05-29 20:16:26  2018-05-29 21:52:37
# 32367          1250 2018-05-30 12:42:19  2018-05-30 13:03:09
# 32393          1152 2018-05-30 13:12:48  2018-05-30 13:32:00
#
#        start station id start station name  end station id end station name  \
# 32                 3185          City Hall            3185        City Hall
# 394                3185          City Hall            3185        City Hall
# ...

# %%
df['starttime'] = pd.to_datetime(df['starttime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  datetime64[ns]
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 2.5+ MB

# %%
df['starttime'].min()
# Out:
# Timestamp('2018-05-01 00:04:47')

# %%
df['starttime'].max()
# Out:
# Timestamp('2018-05-30 13:50:58')

# %%
# 2018-05-01

df.loc[(df['starttime'] > '2018-05-01 00:04:47') & (df['starttime'] < '2018-05-02 00:00:00')]
# Out:
#       tripduration           starttime             stoptime  start station id  \
# 1             1482 2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2              300 2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3              200 2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4              303 2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5              176 2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# ...            ...                 ...                  ...               ...
# 1219          1041 2018-05-01 23:48:09  2018-05-02 00:05:31              3203
# 1220           127 2018-05-01 23:48:20  2018-05-01 23:50:27              3213
# 1221           638 2018-05-01 23:50:06  2018-05-02 00:00:44              3187
# 1222           115 2018-05-01 23:55:37  2018-05-01 23:57:32              3213
# 1223           227 2018-05-01 23:56:13  2018-05-02 00:00:00              3186
#
# ...

# %%
df.loc[(df['starttime'] > '2018-05-01') & (df['starttime'] < '2018-05-02')]
# Out:
#       tripduration           starttime             stoptime  start station id  \
# 0              338 2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1             1482 2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2              300 2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3              200 2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4              303 2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# ...            ...                 ...                  ...               ...
# 1219          1041 2018-05-01 23:48:09  2018-05-02 00:05:31              3203
# 1220           127 2018-05-01 23:48:20  2018-05-01 23:50:27              3213
# 1221           638 2018-05-01 23:50:06  2018-05-02 00:00:44              3187
# 1222           115 2018-05-01 23:55:37  2018-05-01 23:57:32              3213
# 1223           227 2018-05-01 23:56:13  2018-05-02 00:00:00              3186
#
# ...

# %%
# 2 & 3


df.loc[(df['starttime'] > '2018-05-02') & (df['starttime'] <= '2018-05-03')]
# Out:
#       tripduration           starttime             stoptime  start station id  \
# 1224           127 2018-05-02 00:02:08  2018-05-02 00:04:15              3213
# 1225           498 2018-05-02 00:02:22  2018-05-02 00:10:41              3186
# 1226           136 2018-05-02 00:08:56  2018-05-02 00:11:13              3213
# 1227           377 2018-05-02 00:11:33  2018-05-02 00:17:51              3276
# 1228           132 2018-05-02 00:16:28  2018-05-02 00:18:40              3213
# ...            ...                 ...                  ...               ...
# 2494           543 2018-05-02 23:41:20  2018-05-02 23:50:24              3270
# 2495           561 2018-05-02 23:41:16  2018-05-02 23:50:37              3270
# 2496           354 2018-05-02 23:44:29  2018-05-02 23:50:23              3276
# 2497          1072 2018-05-02 23:44:58  2018-05-03 00:02:51              3186
# 2498           161 2018-05-02 23:55:10  2018-05-02 23:57:51              3481
#
# ...

# %%
# Between_time

a = df.loc[(df['starttime'] > '2018-05-01') & (df['starttime'] < '2018-05-02')].set_index('starttime')


a.between_time('00:00:00','02:00:00')
# Out:
#                      tripduration             stoptime  start station id  \
# starttime
# 2018-05-01 00:04:47           338  2018-05-01 00:10:25              3639
# 2018-05-01 01:31:10          1482  2018-05-01 01:55:53              3681
# 2018-05-01 01:31:29           300  2018-05-01 01:35:22              3194
#
#                     start station name  end station id end station name  \
# starttime
# 2018-05-01 00:04:47         Harborside            3199     Newport Pkwy
# 2018-05-01 01:31:10           Grand St            3185        City Hall
# 2018-05-01 01:31:29    McGinley Square            3193     Lincoln Park
#
#                      bikeid                      name_localizedValue  \
# starttime
# 2018-05-01 00:04:47   33558                        Annual Membership
# 2018-05-01 01:31:10   33593                                  24 Hour
# 2018-05-01 01:31:29   29217  FREE Bonus Month with Annual Membership
#
#                        usertype
# starttime
# ...

# %% [markdown]
# # Query

# %%
df.loc[(df['usertype'] == 'Subscriber') & (df['tripduration'] >= 1000)]

# %%
df.query('''
usertype == 'Subscriber' and tripduration >= 1000
''')
# Out:
#        tripduration           starttime             stoptime  \
# 32             2056 2018-05-01 06:25:13  2018-05-01 06:59:30
# 149            1020 2018-05-01 07:51:18  2018-05-01 08:08:19
# 194            1384 2018-05-01 08:07:19  2018-05-01 08:30:24
# 220            2198 2018-05-01 08:17:07  2018-05-01 08:53:46
# 247            1278 2018-05-01 08:25:44  2018-05-01 08:47:02
# ...             ...                 ...                  ...
# 32386          1116 2018-05-30 13:05:36  2018-05-30 13:24:13
# 32388          1802 2018-05-30 13:09:34  2018-05-30 13:39:36
# 32393          1152 2018-05-30 13:12:48  2018-05-30 13:32:00
# 32397          1770 2018-05-30 13:17:41  2018-05-30 13:47:12
# 32426          1130 2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id   start station name  end station id  \
# 32                 3185            City Hall            3185
# 149                3191             Union St            3195
# ...

# %%
# df.loc[(df['start station name'] == 'Harborside')|(df['start station name'] =='City Hall' )]

df.query('''
`start station name` == 'Harborside' or `start station name` == 'City Hall'
''')
# Out:
#        tripduration           starttime             stoptime  \
# 0               338 2018-05-01 00:04:47  2018-05-01 00:10:25
# 3               200 2018-05-01 02:03:29  2018-05-01 02:06:40
# 11              704 2018-05-01 05:23:26  2018-05-01 05:35:11
# 32             2056 2018-05-01 06:25:13  2018-05-01 06:59:30
# 49              356 2018-05-01 06:40:07  2018-05-01 06:46:03
# ...             ...                 ...                  ...
# 32393          1152 2018-05-30 13:12:48  2018-05-30 13:32:00
# 32401           225 2018-05-30 13:18:06  2018-05-30 13:21:52
# 32411           873 2018-05-30 13:29:58  2018-05-30 13:44:32
# 32412           266 2018-05-30 13:30:11  2018-05-30 13:34:38
# 32413           249 2018-05-30 13:35:14  2018-05-30 13:39:24
#
#        start station id start station name  end station id   end station name  \
# 0                  3639         Harborside            3199       Newport Pkwy
# ...
