# %% [markdown]
# # Type casting
#
# - converting one data type to another

# %%
# 1st method

a = float(99)

print(a , type(a))
# Out:
# 99.0 <class 'float'>

# %%
print(a)
# Out:
# 99.0

# %%
# 2 nd method

a = 99

print(float(a) , type(float(a)))
# Out:
# 99.0 <class 'float'>

# %%
print(a)
# Out:
# 99

# %%
a = int(123.897)

print(a , type(a))
# Out:
# 123 <class 'int'>

# %%
a = round(123.897)

print(a , type(a))
# Out:
# 124 <class 'int'>

# %%
a = int(99.99999999999)

print(a , type(a))
# Out:
# 99 <class 'int'>

# %%
a = int(99.99999999999)

print(a , type(a))

# %%
a = complex(98)

print(a , type(a))
# Out:
# (98+0j) <class 'complex'>

# %%
a = complex(98.6777)

print(a , type(a))
# Out:
# (98.6777+0j) <class 'complex'>

# %%
a = int(77+9j)

print(a , type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a = int(77+9j)
#       3 print(a , type(a))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
a = float(77+0j)

print(a , type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 a = float(77+0j)
#       3 print(a , type(a))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
a = 77+9j

print(a , type(a))

print(a.real)
print(a.imag)
# Out:
# (77+9j) <class 'complex'>
# 77.0
# 9.0

# %%
a = bool(-55)

print(a , type(a))
# Out:
# True <class 'bool'>

# %%
- int --> 0 is false and rest all are true
- float --> 0.0 is false and rest all are true
- complex --> 0 + 0j is false and rest all are true
- string - '' is false and rest all are true
- None - Always False

[] , () , {}

# %%
a = bool(0.00000001)

print(a , type(a))
# Out:
# True <class 'bool'>

# %%
a = bool(34+54j)

print(a , type(a))
# Out:
# True <class 'bool'>

# %%
a = bool(0+0j)

print(a , type(a))
# Out:
# False <class 'bool'>

# %%
a = bool(' ')

print(a , type(a))
# Out:
# True <class 'bool'>

# %%
a = bool(None)

print(a , type(a))
# Out:
# False <class 'bool'>

# %%
a = bool([43])

print(a , type(a))
# Out:
# True <class 'bool'>

# %%
a = '123'

print(a , type(a))
# Out:
# 123 <class 'str'>

# %%
a = int('123')

print(a , type(a))
# Out:
# 123 <class 'int'>

# %%
a = int('123abc')

print(a , type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 a = int('123abc')
#       3 print(a , type(a))
#
# ValueError: invalid literal for int() with base 10: '123abc'

# %%
a = int('123.456')

print(a , type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 a = int('123.456')
#       3 print(a , type(a))
#
# ValueError: invalid literal for int() with base 10: '123.456'

# %%
a = float('123.456')

print(a , type(a))
# Out:
# 123.456 <class 'float'>

# %%
a = int(float('123.8888'))

print(a , type(a))
# Out:
# 123 <class 'int'>

# %% [markdown]
# # Eval

# %%
a = int('123')

print(a , type(a))
# Out:
# 123 <class 'int'>

# %%
a = float('123.456')

print(a , type(a))
# Out:
# 123.456 <class 'float'>

# %%
a = eval('123')

print(a , type(a))
# Out:
# 123 <class 'int'>

# %%
a = eval('123.5456')

print(a , type(a))
# Out:
# 123.5456 <class 'float'>

# %%
a = eval('[34.546,54.65,56,65]')

print(a , type(a))
# Out:
# [34.546, 54.65, 56, 65] <class 'list'>

# %%
a = eval('123.54')

print(a , type(a))
# Out:
# 123.54 <class 'float'>

# %% [markdown]
# # Input function
#
# - Which allows the user to input any values
# - The input will always be in a form of string

# %%
a = input('Enter a value : ')

print(a , type(a))
# Out:
# Enter a value : 123
# 123 <class 'str'>

# %%
'10' + '20'
# Out:
# '1020'

# %%
10 + 20
# Out:
# 30

# %%
# WAP to That take 2 inputs - and the out 30

# %%
a= int(input('Enter a Value: '))
b= int(input('Enter a Value: '))


print((a+b))
# Out:
# Enter a Value: 123
# Enter a Value: 45.6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 2
#       1 a=int(input('Enter a Value: '))
# ----> 2 b=int(input('Enter a Value: '))
#       5 print((a+b))
#
# ValueError: invalid literal for int() with base 10: '45.6'

# %%
a= eval(input('Enter a Value: '))
b= eval(input('Enter a Value: '))


print((a+b))
# Out:
# Enter a Value: 10
# Enter a Value: 3544.5747
# 3554.5747

# %%
take an inpou --> enter the mobile -->


+91-9023489302

# %%
a = int(input("Enter the mobile number:"))

print("+91-"+str(a))
# Out:
# Enter the mobile number:34534534
# +91-34534534

# %%
a = input('Enter first name: ')
b = int(input('Enter mobile no: '))

c = 'My first name is '+ a + ' and second name is '+ str(b) # string concatination

print(c)
# Out:
# Enter first name: abc
# Enter mobile no: 1234568
# My first name is abc and second name is 1234568

# %% [markdown]
# # Format string

# %%
# 1st method

a = input('Enter first name: ')
b = int(input('Enter mobile no: '))

c = 'My first name is {} and second name is {}'.format(a , b)

print(c)
# Out:
# Enter first name: abc
# Enter mobile no: 152
# My first name is abc and second name is 152

# %%
# 1st method

a = input('Enter first name: ')
b = int(input('Enter mobile no: '))

c = f'My first name is {a} and second name is {b}'

print(c)
# Out:
# Enter first name: abc
# Enter mobile no: 13245
# My first name is abc and second name is 13245

# %%
a= eval(input('Enter a Value: '))
b= eval(input('Enter a Value: '))


print(a+b)
# Out:
# Enter a Value: 10
# Enter a Value: 20
# 30

# %%
a = eval(input('Enter number 1 : '))
b = eval(input('Enter number 2 : '))

c = a + b

print('The Addition of two numbers ' + str(a) + ' and '+str(b)+ ' = '+ str(c))

print(f'The Addition of two numbers {a} and {b} = {c}')

print('The Addition of two numbers {} and {} = {}'.format(a,b,c))
# Out:
# Enter number 1 : 10
# Enter number 2 : 20
# The Addition of two numbers 10 and 20 = 30
# The Addition of two numbers 10 and 20 = 30

# %% [markdown]
# # Output function, Int
