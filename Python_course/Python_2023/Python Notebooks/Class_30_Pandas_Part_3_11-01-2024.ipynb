# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Addition and deleting of columns

# %%
df = pd.read_csv('datasets/international_org.csv')
df
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
df['new_col_1'] = 1945

# %%
df['new_col_2'] = [23,43,65,34,56,56]

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2
# 0               FAO        Rome       1945         23
# 1               ICJ   The Hague       1945         43
# 2               IMF  Washington       1945         65
# 3            UNESCO       Paris       1945         34
# 4               UNO    New York       1945         56
# 5        World Bank  Washington       1945         56

# %% [markdown]
# # Apply
#
# - One single column
#
# expression or even condition is also allowed

# %%
df['new_col_3'] = df['new_col_2'].apply(lambda x : x/2)

# %%
df['new_col_4'] = df['new_col_2'].apply(lambda x :'even' if x%2==0 else 'odd')

# %%
df['new_col_5'] = df['Headquater'].apply(lambda x : x[0])

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3 new_col_4  \
# 0               FAO        Rome       1945         23       11.5       odd
# 1               ICJ   The Hague       1945         43       21.5       odd
# 2               IMF  Washington       1945         65       32.5       odd
# 3            UNESCO       Paris       1945         34       17.0      even
# 4               UNO    New York       1945         56       28.0      even
# 5        World Bank  Washington       1945         56       28.0      even
#
#   new_col_5
# 0         R
# 1         T
# 2         W
# 3         P
# 4         N
# 5         W

# %% [markdown]
# # Assign
#
# - Only expression is allowed on multiple column condition is not allowed

# %%
df = df.assign(new_col_6 = lambda x : x.new_col_2 * x.new_col_3)

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3 new_col_4  \
# 0               FAO        Rome       1945         23       11.5       odd
# 1               ICJ   The Hague       1945         43       21.5       odd
# 2               IMF  Washington       1945         65       32.5       odd
# 3            UNESCO       Paris       1945         34       17.0      even
# 4               UNO    New York       1945         56       28.0      even
# 5        World Bank  Washington       1945         56       28.0      even
#
#   new_col_5  new_col_6
# 0         R      264.5
# 1         T      924.5
# 2         W     2112.5
# 3         P      578.0
# 4         N     1568.0
# 5         W     1568.0

# %%
df['new_col_7'] = list(map((lambda x,y :x *y) , df['new_col_2'] , df['new_col_3']))

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3 new_col_4  \
# 0               FAO        Rome       1945         23       11.5       odd
# 1               ICJ   The Hague       1945         43       21.5       odd
# 2               IMF  Washington       1945         65       32.5       odd
# 3            UNESCO       Paris       1945         34       17.0      even
# 4               UNO    New York       1945         56       28.0      even
# 5        World Bank  Washington       1945         56       28.0      even
#
#   new_col_5  new_col_6  new_col_7
# 0         R      264.5      264.5
# 1         T      924.5      924.5
# 2         W     2112.5     2112.5
# 3         P      578.0      578.0
# 4         N     1568.0     1568.0
# 5         W     1568.0     1568.0

# %% [markdown]
# # Deleting column

# %%
del df['new_col_7']

# %%
del [df['new_col_6'] , df['new_col_5']]

# %% [markdown]
# # drop

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3 new_col_4
# 0               FAO        Rome       1945         23       11.5       odd
# 1               ICJ   The Hague       1945         43       21.5       odd
# 2               IMF  Washington       1945         65       32.5       odd
# 3            UNESCO       Paris       1945         34       17.0      even
# 4               UNO    New York       1945         56       28.0      even
# 5        World Bank  Washington       1945         56       28.0      even

# %%
df.drop(columns= 'new_col_4') # inplace = False
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3
# 0               FAO        Rome       1945         23       11.5
# 1               ICJ   The Hague       1945         43       21.5
# 2               IMF  Washington       1945         65       32.5
# 3            UNESCO       Paris       1945         34       17.0
# 4               UNO    New York       1945         56       28.0
# 5        World Bank  Washington       1945         56       28.0

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3 new_col_4
# 0               FAO        Rome       1945         23       11.5       odd
# 1               ICJ   The Hague       1945         43       21.5       odd
# 2               IMF  Washington       1945         65       32.5       odd
# 3            UNESCO       Paris       1945         34       17.0      even
# 4               UNO    New York       1945         56       28.0      even
# 5        World Bank  Washington       1945         56       28.0      even

# %%
df.drop(columns= 'new_col_4' , inplace = True) # inplace = True

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1  new_col_2  new_col_3
# 0               FAO        Rome       1945         23       11.5
# 1               ICJ   The Hague       1945         43       21.5
# 2               IMF  Washington       1945         65       32.5
# 3            UNESCO       Paris       1945         34       17.0
# 4               UNO    New York       1945         56       28.0
# 5        World Bank  Washington       1945         56       28.0

# %%
df.drop(columns= ['new_col_3' , 'new_col_2'] , inplace = True)

# %%
df
# Out:
#   Organization Name  Headquater  new_col_1
# 0               FAO        Rome       1945
# 1               ICJ   The Hague       1945
# 2               IMF  Washington       1945
# 3            UNESCO       Paris       1945
# 4               UNO    New York       1945
# 5        World Bank  Washington       1945

# %% [markdown]
# # Add rows and delete rows

# %%
df = pd.read_csv('datasets/imdb_rating.csv')

df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
new_show = [9.5 , 'Prison break' , 'Crime' , 60]

# %%
df.loc[3] = new_show

# %%
df.loc[10] = new_show

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.5                                   Prison break      Crime
#
#     duration
# 0        142
# 1        175
# 2        200
# 3         60
# ...

# %%
len(df)
# Out:
# 11

# %%
new_show = [[9.5 , 'Prison break' , 'Crime' , 60] ,
           [7.5 , 'Friends' , 'Drama' , 60] ,
           [8.5 , 'Peaky Blinders' , 'Crime' , 90]]

# %%
for i in new_show:
    df.loc[len(df)] = i

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.5                                   Prison break      Crime
# 11          9.5                                   Prison break      Crime
# ...

# %% [markdown]
# # Deleting the rows

# %%
df.drop(index= 11)
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.5                                   Prison break      Crime
# 12          7.5                                        Friends      Drama
# ...

# %%
df.drop(index= [11 , 5 , 12 ,2])
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.5                                   Prison break      Crime
# 13          8.5                                 Peaky Blinders      Crime
#
#     duration
# 0        142
# 1        175
# 3         60
# 4        154
# 6        161
# 7        201
# 8        195
# 9        139
# 10        60
# ...

# %%
df.loc[df['genre'] == 'Drama'].index
# Out:
# Int64Index([5, 9, 12], dtype='int64')

# %%
df.drop(index = df.loc[df['genre'] == 'Drama'].index)
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 10          9.5                                   Prison break      Crime
# 11          9.5                                   Prison break      Crime
# 13          8.5                                 Peaky Blinders      Crime
#
#     duration
# 0        142
# 1        175
# 2        200
# 3         60
# ...

# %%
for i in df.index:
    if df.loc[i]['genre'] == 'Drama':
        df.drop(index = i , inplace = True)

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 10          9.5                                   Prison break      Crime
# 11          9.5                                   Prison break      Crime
# 13          8.5                                 Peaky Blinders      Crime
#
#     duration
# 0        142
# 1        175
# 2        200
# 3         60
# ...

# %%
df.reset_index() # Drop = False . Inplace = False
# Out:
#     index  star_rating                                          title  \
# 0       0          9.3                       The Shawshank Redemption
# 1       1          9.2                                  The Godfather
# 2       2          9.1                         The Godfather: Part II
# 3       3          9.5                                   Prison break
# 4       4          8.9                                   Pulp Fiction
# 5       6          8.9                 The Good, the Bad and the Ugly
# 6       7          8.9  The Lord of the Rings: The Return of the King
# 7       8          8.9                               Schindler's List
# 8      10          9.5                                   Prison break
# 9      11          9.5                                   Prison break
# 10     13          8.5                                 Peaky Blinders
#
#         genre  duration
# 0       Crime       142
# 1       Crime       175
# 2       Crime       200
# 3       Crime        60
# ...

# %%
df.reset_index(drop = True , inplace = True)

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.5                                   Prison break      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                 The Good, the Bad and the Ugly    Western
# 6           8.9  The Lord of the Rings: The Return of the King  Adventure
# 7           8.9                               Schindler's List  Biography
# 8           9.5                                   Prison break      Crime
# 9           9.5                                   Prison break      Crime
# 10          8.5                                 Peaky Blinders      Crime
#
#     duration
# 0        142
# 1        175
# 2        200
# 3         60
# ...

# %%
df.loc[df['duration'] <= 100].index
# Out:
# Int64Index([3, 8, 9, 10], dtype='int64')

# %%
df.drop(index = df.loc[df['duration'] <= 100].index)
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                 The Good, the Bad and the Ugly    Western
# 6          8.9  The Lord of the Rings: The Return of the King  Adventure
# 7          8.9                               Schindler's List  Biography
#
#    duration
# 0       142
# 1       175
# 2       200
# 4       154
# 5       161
# 6       201
# 7       195

# %% [markdown]
# # Sorting the data frame

# %%
df = pd.read_csv('datasets/unsorted_imdb_rating.csv')

df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.sort_values(by = 'duration' , ascending= False)
# Out:
#    star_rating                                          title      genre  \
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 2          9.2                         The Godfather: Part II      Crime
# 8          8.3                               Schindler's List  Biography
# 1          9.1                                  The Godfather      Crime
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 4          8.9                                   Pulp Fiction      Crime
# 3          9.0                                The Dark Knight     Action
# 0          9.3                       The Shawshank Redemption      Crime
# 9          8.1                                     Fight Club      Drama
# 5          8.8                                   12 Angry Men      Drama
#
#    duration
# 7       201
# 2       200
# 8       195
# 1       175
# 6       161
# 4       154
# 3       152
# 0       142
# 9       139
# 5        96

# %%
df.sort_values(by = ['star_rating' , 'duration'] , ascending= [True , False] , ignore_index= True)
# Out:
#    star_rating                                          title      genre  \
# 0          8.1                                     Fight Club      Drama
# 1          8.3                               Schindler's List  Biography
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.8                                   12 Angry Men      Drama
# 4          8.9  The Lord of the Rings: The Return of the King  Adventure
# 5          8.9                                   Pulp Fiction      Crime
# 6          9.0                                The Dark Knight     Action
# 7          9.1                                  The Godfather      Crime
# 8          9.2                         The Godfather: Part II      Crime
# 9          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 0       139
# 1       195
# 2       161
# 3        96
# 4       201
# 5       154
# 6       152
# 7       175
# 8       200
# 9       142

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
lst = [['Salahudin',37, 8] , ['Sriram', 29 , 3], ['Mithun', 38 , 8],
       ['Chetan', 27 , 4] , ['Jayanth', 37 , 13], ['Santhosh', 25 , 2], ['Ashok', 40 , 17] , ['Abc' , 37 , 8]]

# - 1. Sort my data  exp
# - 2. Sort the data grades
# - 3. alphabetic order 

# for i in range(len(lst)):
#     for j in range(len(lst)-1-i):
#         if lst[j][-1]>lst[j+1][-1]: # exp
#             lst[j] , lst[j+1] = lst[j+1] , lst[j]
#         elif lst[j][-1] == lst[j+1][-1]: # Grades
#             if lst[j][1] > lst[j+1][1]:
#                 lst[j] , lst[j+1] = lst[j+1] , lst[j]
#             elif lst[j][1] == lst[j+1][1]: # Alpha
#                 if lst[j][0] > lst[j+1][0]:
#                     lst[j] , lst[j+1] = lst[j+1] , lst[j]
            
            
# lst

# %%
lst = [['Salahudin',37, 8] , ['Sriram', 29 , 3], ['Mithun', 38 , 8],
       ['Chetan', 27 , 4] , ['Jayanth', 37 , 13], ['Santhosh', 25 , 2], ['Ashok', 40 , 17] , ['Abc' , 37 , 8]]


df = pd.DataFrame(lst , columns= ['Name' , 'Age' , 'Experience'])

df
# Out:
#         Name  Age  Experience
# 0  Salahudin   37           8
# 1     Sriram   29           3
# 2     Mithun   38           8
# 3     Chetan   27           4
# 4    Jayanth   37          13
# 5   Santhosh   25           2
# 6      Ashok   40          17
# 7        Abc   37           8

# %%
df.sort_values(by=['Experience','Age','Name'],ignore_index=True)
# Out:
#         Name  Age  Experience
# 0   Santhosh   25           2
# 1     Sriram   29           3
# 2     Chetan   27           4
# 3        Abc   37           8
# 4  Salahudin   37           8
# 5     Mithun   38           8
# 6    Jayanth   37          13
# 7      Ashok   40          17

# %% [markdown]
# # Replace

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.at[2 , 'genre'] = 'xyz'

# %%
for i in df.index:
    if df.at[i , 'genre'] == 'Crime':
        df.at[i , 'genre'] = 'xyz'

# %%
for i in df.index:
    if df.loc[i , 'genre'] == 'Crime':
        df.loc[i , 'genre'] = 'xyz'

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption        xyz
# 1          9.1                                  The Godfather        xyz
# 2          9.2                         The Godfather: Part II        xyz
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction        xyz
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.loc[1 , 'genre']
# Out:
# 'Crime'

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption        xyz
# 1          9.1                                  The Godfather        xyz
# 2          9.2                         The Godfather: Part II        xyz
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction        xyz
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df = pd.read_csv('datasets/weather_data_replace.csv')

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df['windspeed'].replace(-99999 , 100)

# %%
df.replace(-99999 , 100)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017          100          7  Sunny
# 2  1/3/2017           28        100   Snow
# 3  1/4/2017          100          7      0
# 4  1/5/2017           32        100   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df.replace([-99999 , '0'] , 100)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017          100          7  Sunny
# 2  1/3/2017           28        100   Snow
# 3  1/4/2017          100          7    100
# 4  1/5/2017           32        100   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5    100

# %%
df.replace({'temperature' :-99999 ,
           'windspeed' :7 , 
           'event' : '0'} , 100)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017          100        100  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017          100        100    100
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5    100

# %%
df.replace({'temperature' :-99999 ,
           'windspeed' :7 , 
           'event' : '0'} , {'temperature' :100 ,
           'windspeed' :200 , 
           'event' : 300})
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017          100        200  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017          100        200    300
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5    300

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df['usertype'].replace(['Subscriber' , 'Customer'] , [0 , 1] , inplace = True)

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
#
