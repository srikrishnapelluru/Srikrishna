# %%
import pandas as pd
import numpy as np

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# # Concatination

# %%
df = pd.concat([india_weather , us_weather] , ignore_index= True)

df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather , us_weather], axis = 1)

df
# Out:
#        city  temperature  humidity      city  temperature  humidity
# 0    mumbai           32        80  new york           21        68
# 1     delhi           45        60   chicago           14        65
# 2  banglore           30        78   orlando           35        75

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35]
})
us_weather
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df = pd.concat([india_weather , us_weather] , ignore_index= True)

df
# Out:
#        city  temperature  humidity
# 0    mumbai           32      80.0
# 1     delhi           45      60.0
# 2  banglore           30      78.0
# 3  new york           21       NaN
# 4   chicago           14       NaN
# 5   orlando           35       NaN

# %%
df = pd.concat([india_weather , us_weather] , keys= ['India' , 'Us'])

df
# Out:
#              city  temperature  humidity
# India 0    mumbai           32      80.0
#       1     delhi           45      60.0
#       2  banglore           30      78.0
# Us    0  new york           21       NaN
#       1   chicago           14       NaN
#       2   orlando           35       NaN

# %%
df.loc['India']
# Out:
#        city  temperature  humidity
# 0    mumbai           32      80.0
# 1     delhi           45      60.0
# 2  banglore           30      78.0

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
pd.concat([df1 , df2])
# Out:
#        city  temperature  humidity
# 0  new york         21.0       NaN
# 1   chicago         14.0       NaN
# 2   orlando         35.0       NaN
# 0   chicago          NaN      65.0
# 1  new york          NaN      68.0
# 2   orlando          NaN      75.0

# %% [markdown]
# # Merge

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
pd.merge(df1 , df2 , on = 'city') # 'inner'
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
pd.merge(df1 , df2 , on = 'city') # 'inner'
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
pd.merge(df1 , df2 , on = 'city' , how = 'left')
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
pd.merge(df1 , df2 , on = 'city' , how = 'right')
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
pd.merge(df1 , df2 , on = 'city' , how = 'outer')
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando" , 'orlando'],
    "humidity": [65,68,75 , 30],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75
# 3   orlando        30

# %%
pd.merge(df1 , df2 , on = 'city' )
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75
# 3   orlando           35        30

# %%
df1 = pd.DataFrame({
    "names": ["emp_1","emp_2","emp_3"],
})
df1
# Out:
#    names
# 0  emp_1
# 1  emp_2
# 2  emp_3

# %%
df2 = pd.DataFrame({
    "details": ['age','salary','exp' ],
})
df2
# Out:
#   details
# 0     age
# 1  salary
# 2     exp

# %%
pd.merge(df1 , df2  , how = 'cross')
# Out:
#    names details
# 0  emp_1     age
# 1  emp_1  salary
# 2  emp_1     exp
# 3  emp_2     age
# 4  emp_2  salary
# 5  emp_2     exp
# 6  emp_3     age
# 7  emp_3  salary
# 8  emp_3     exp

# %%
df1 = pd.DataFrame({
    "Employees": ["Salahudin","Dinesh","Indrajeet", "Kiran" , 'New_emp'],
    "Emp_id": [1,2,3, 4 , 5]
})
df1
# Out:
#    Employees  Emp_id
# 0  Salahudin       1
# 1     Dinesh       2
# 2  Indrajeet       3
# 3      Kiran       4
# 4    New_emp       5

# %%
df2 = pd.DataFrame({
    "Department": ["Dev" , 'Prod',"QA","Testing", 'Dev ops',"HR"],
    "Emp_id": [1,1,2,3,3, 4]
})
df2
# Out:
#   Department  Emp_id
# 0        Dev       1
# 1       Prod       1
# 2         QA       2
# 3    Testing       3
# 4    Dev ops       3
# 5         HR       4

# %%
df3 = pd.DataFrame({
    "Salary": [34343434,565465465,546546546,54654654 , 454545],
    "Emp_id": [1,2,3, 4 , 5]
})
df3
# Out:
#       Salary  Emp_id
# 0   34343434       1
# 1  565465465       2
# 2  546546546       3
# 3   54654654       4
# 4     454545       5

# %%
emp_name , emp_id , dep , salary

# %%
df_4 = pd.merge(df1,df2 , on = 'Emp_id' , how = 'outer')

df_4
# Out:
#    Employees  Emp_id Department
# 0  Salahudin       1        Dev
# 1  Salahudin       1       Prod
# 2     Dinesh       2         QA
# 3  Indrajeet       3    Testing
# 4  Indrajeet       3    Dev ops
# 5      Kiran       4         HR
# 6    New_emp       5        NaN

# %%
pd.merge(df_4 , df3 , on ='Emp_id' )
# Out:
#    Employees  Emp_id Department     Salary
# 0  Salahudin       1        Dev   34343434
# 1  Salahudin       1       Prod   34343434
# 2     Dinesh       2         QA  565465465
# 3  Indrajeet       3    Testing  546546546
# 4  Indrajeet       3    Dev ops  546546546
# 5      Kiran       4         HR   54654654
# 6    New_emp       5        NaN     454545

# %% [markdown]
# # Group by

# %%
df = pd.read_csv('datasets/weather_by_cities_group_by.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df['city'].unique()
# Out:
# array(['new york', 'mumbai', 'paris'], dtype=object)

# %%
df['event'].value_counts()
# Out:
# Sunny     4
# Cloudy    3
# Rain      2
# Fog       2
# Snow      1
# Name: event, dtype: int64

# %%
- Max temp for each city

# %%
df['temperature'].max()
# Out:
# 92

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g = df.groupby('city')

list(g)
# Out:
# [('mumbai',
#           day    city  temperature  windspeed  event
#   4  1/1/2017  mumbai           90          5  Sunny
#   5  1/2/2017  mumbai           85         12    Fog
#   6  1/3/2017  mumbai           87         15    Fog
#   7  1/4/2017  mumbai           92          5   Rain),
#  ('new york',
#           day      city  temperature  windspeed  event
#   0  1/1/2017  new york           32          6   Rain
#   1  1/2/2017  new york           36          7  Sunny
#   2  1/3/2017  new york           28         12   Snow
#   3  1/4/2017  new york           33          7  Sunny),
#  ('paris',
#            day   city  temperature  windspeed   event
#   8   1/1/2017  paris           45         20   Sunny
#   9   1/2/2017  paris           50         13  Cloudy
#   10  1/3/2017  paris           54          8  Cloudy
#   11  1/4/2017  paris           42         10  Cloudy)]

# %%
g.max()['temperature']
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
g.max()['windspeed']
# Out:
# city
# mumbai      15
# new york    12
# paris       20
# Name: windspeed, dtype: int64

# %%
# Get group

g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g.mean(numeric_only= True)['windspeed']
# Out:
# city
# mumbai       9.25
# new york     8.00
# paris       12.75
# Name: windspeed, dtype: float64

# %% [markdown]
# # Handling null values

# %%
### Fillna

df = pd.read_csv('datasets/weather_data_nan.csv')

df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.fillna(100)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017        100.0        9.0   Sunny
# 2   1/5/2017         28.0      100.0    Snow
# 3   1/6/2017        100.0        7.0     100
# 4   1/7/2017         32.0      100.0    Rain
# 5   1/8/2017        100.0      100.0   Sunny
# 6   1/9/2017        100.0      100.0     100
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.fillna({'temperature' : 100 , 
          'windspeed' : 200 , 
          'event' : 300})
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017        100.0        9.0   Sunny
# 2   1/5/2017         28.0      200.0    Snow
# 3   1/6/2017        100.0        7.0     300
# 4   1/7/2017         32.0      200.0    Rain
# 5   1/8/2017        100.0      200.0   Sunny
# 6   1/9/2017        100.0      200.0     300
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df['temperature'].fillna((100))
# Out:
# 0     32.0
# 1    100.0
# 2     28.0
# 3    100.0
# 4     32.0
# 5    100.0
# 6    100.0
# 7     34.0
# 8     40.0
# Name: temperature, dtype: float64

# %%
df.fillna({'temperature' : 100 , 
          'windspeed' : 200 , 
          'event' : 300})
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017        100.0        9.0   Sunny
# 2   1/5/2017         28.0      200.0    Snow
# 3   1/6/2017        100.0        7.0     300
# 4   1/7/2017         32.0      200.0    Rain
# 5   1/8/2017        100.0      200.0   Sunny
# 6   1/9/2017        100.0      200.0     300
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df['temperature'].mean()
# Out:
# 33.2

# %%
df['windspeed'].median()
# Out:
# 8.0

# %%
df['event'].mode()[0]
# Out:
# 'Sunny'

# %%
df.fillna({'temperature' : df['temperature'].mean() , 
          'windspeed' : df['windspeed'].median() , 
          'event' : df['event'].mode()[0]})
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.0    Snow
# 3   1/6/2017         33.2        7.0   Sunny
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         33.2        8.0   Sunny
# 6   1/9/2017         33.2        8.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.dropna()
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.dropna(thresh= 2)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.dropna(thresh= 3)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.dropna(axis = 1)
# Out:
#          day
# 0   1/1/2017
# 1   1/4/2017
# 2   1/5/2017
# 3   1/6/2017
# 4   1/7/2017
# 5   1/8/2017
# 6   1/9/2017
# 7  1/10/2017
# 8  1/11/2017

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.fillna({'temperature' : df['temperature'].mean() , 
          'windspeed' : df['windspeed'].median() , 
          'event' : df['event'].mode()[0]} , inplace = True)

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.0    Snow
# 3   1/6/2017         33.2        7.0   Sunny
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         33.2        8.0   Sunny
# 6   1/9/2017         33.2        8.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# # Saving the data frame

# %%
df.to_csv('clean_data.csv')

# %%
df.to_csv('datasets/weather_data_nan.csv')
